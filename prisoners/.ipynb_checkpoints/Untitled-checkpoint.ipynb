# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("prisoners.csv")

# %%
df.head(5)
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
df.tail(5)
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# ...

# %%
df.describe(include = 'all')
# Out:
#               STATE/UT    YEAR  \
# count               35    35.0
# unique              35     NaN
# top     Andhra Pradesh     NaN
# freq                 1     NaN
# mean               NaN  2013.0
# std                NaN     0.0
# min                NaN  2013.0
# 25%                NaN  2013.0
# 50%                NaN  2013.0
# 75%                NaN  2013.0
# max                NaN  2013.0
#
#         No. of Inmates benefitted by Elementary Education  \
# count                                           35.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          1057.914286
# std                                           2078.196777
# min                                              0.000000
# 25%                                              0.000000
# ...

# %%
df.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [STATE/UT, YEAR, No. of Inmates benefitted by Elementary Education, No. of Inmates benefitted by Adult Education, No. of Inmates benefitted by Higher Education, No. of Inmates benefitted by Computer Course]
# Index: []

# %%
nan_values = df[df.isna().any(axis=1)]

print (nan_values)
# Out:
# Empty DataFrame
# Columns: [STATE/UT, YEAR, No. of Inmates benefitted by Elementary Education, No. of Inmates benefitted by Adult Education, No. of Inmates benefitted by Higher Education, No. of Inmates benefitted by Computer Course]
# Index: []

# %%
df.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
print(df.iloc[df[(df.isnull().sum(axis=1) >= 1).index])
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp/ipykernel_6620/20163280.py", line 1
#     print(df.iloc[df[(df.isnull().sum(axis=1) >= 1).index])
#                                                           ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df.loc[df['No. of Inmates benefitted by Elementary Education','No. of Inmates benefitted by Adult Education','No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Computer Course'] >= 1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
rslt_df = df.loc[(df['STATE/UT'] == 0) & df['YEAR' == 0].isin(options)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc[0:]
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
df.loc[df.(No.of Inmates benefitted by Elementary Education == 0), :]
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp/ipykernel_6620/1835666608.py", line 1
#     df.loc[df.(No.of Inmates benefitted by Elementary Education == 0), :]
#               ^
# SyntaxError: invalid syntax

# %%
df.loc[
    (df.No.of Inmates benefitted by Elementary Education == 0) & (df.No. of Inmates benefitted by Adult Education == 0),  ['STATE/UT','YEAR'],]
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp/ipykernel_6620/3731072706.py", line 2
#     (df.No.of Inmates benefitted by Elementary Education == 0) & (df.No. of Inmates benefitted by Adult Education == 0),  ['STATE/UT','YEAR'],]
#               ^
# SyntaxError: invalid syntax

# %%
indexes = df.loc[df['No. of Inmates benefitted by Elementary Education']==0]
print(indexes)
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 15                                                  0
# 17                                                  0
# 18                                                  0
# 22                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
# ...

# %%
df["STATE/UT"]
# Out:
# 0        Andhra Pradesh
# 1     Arunachal Pradesh
# 2                 Assam
# 3                 Bihar
# 4           Chhatisgarh
# 5                   Goa
# 6               Gujarat
# 7               Haryana
# 8      Himachal Pradesh
# 9       Jammu & Kashmir
# 10            Jharkhand
# 11            Karnataka
# 12               Kerala
# 13       Madhya Pradesh
# 14          Maharashtra
# 15              Manipur
# 16            Meghalaya
# 17              Mizoram
# 18             Nagaland
# 19               Orissa
# 20               Punjab
# 21            Rajasthan
# 22               Sikkim
# 23            Tamilnadu
# 24              Tripura
# 25        Uttar Pradesh
# 26          Uttaranchal
# 27          West Bengal
# 28        A & N Islands
# 29           Chandigarh
# 30         D & N Haveli
# 31          Daman & Diu
# 32                Delhi
# 33          Lakshadweep
# 34          Pondicherry
# Name: STATE/UT, dtype: object
